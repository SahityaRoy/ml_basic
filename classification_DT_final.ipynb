# %% [markdown]
# # Medical data classification using Decision Tree

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
from scipy.io import loadmat
#path="/content/drive/MyDrive/UEM/AIML LAB/Classification/"
path="/content/drive/MyDrive/AIML/Classification/"
data = loadmat(path+'pima_dataset.mat')
X=data['norm_data']
y=data['target']
X.shape
# Out:
# (768, 8)

# %%
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %%
from sklearn import tree

# %%
from sklearn.metrics import *

# %% [markdown]
# # Classification performance measure function

# %%
def classification_performance(conf_matrix):
    accureacy=(conf_matrix[0][0]+conf_matrix[1][1])/(conf_matrix[0][0]+conf_matrix[0][1]+conf_matrix[1][0]+conf_matrix[1][1])
    recall=(conf_matrix[0][0])/(conf_matrix[0][0]+conf_matrix[1][0])
    specificity=(conf_matrix[1][1])/(conf_matrix[0][1]+conf_matrix[1][1])
    precision=(conf_matrix[0][0])/(conf_matrix[0][0]+conf_matrix[0][1])
    F1_score=(2*precision*recall)/(precision+recall)
    GM=math.sqrt(recall*specificity)
    FPR=1-specificity
    return accureacy,recall,specificity,precision,F1_score,GM,FPR

# %%
k=10;
kf = KFold(n_splits=10)
acc=np.zeros(k,float)
recall=np.zeros(k,float)
spec=np.zeros(k,float)
precision=np.zeros(k,float)
F1=np.zeros(k,float)
GM=np.zeros(k,float)
FPR=np.zeros(k,float)
iter=0;
for train, test in kf.split(X):
    
    print("Fold:%d" % (iter))
    #print("%s %s" % (train, test))
    X_train=X[train]
    y_train=y[train]
    X_test=X[test]
    y_test=y[test]
    hidden_nodes=X_train.shape[1]
    clf = tree.DecisionTreeClassifier()
    clf.fit(X_train, y_train)
    y_pred=clf.predict(X_test)
    conf_matrix=confusion_matrix(y_test, y_pred)
    acc[iter], recall[iter], spec[iter], precision[iter], F1[iter], GM[iter], FPR[iter]=classification_performance(conf_matrix)
    print("Accuracy: %0.2f, Recall=%0.2f, specificity=%0.2f, precision=%0.2f, F1=%0.2f, GM=%0.2f, FPR=%0.2f" % (acc[iter], recall[iter], spec[iter], precision[iter], F1[iter], GM[iter], FPR[iter]))
    iter=iter+1
print('=======================================AVERAGE OVER K-FOLD===================================')
print("Accuracy: %0.2f, Recall=%0.2f, specificity=%0.2f, precision=%0.2f, F1=%0.2f, GM=%0.2f, FPR=%0.2f" % (acc.mean(), recall.mean(), spec.mean(), precision.mean(), F1.mean(), GM.mean(), FPR.mean()))
# Out:
# Fold:0
# Accuracy: 0.62, Recall=0.67, specificity=0.55, precision=0.71, F1=0.69, GM=0.61, FPR=0.45
# Fold:1
# Accuracy: 0.78, Recall=0.83, specificity=0.63, precision=0.87, F1=0.85, GM=0.72, FPR=0.37
# Fold:2
# Accuracy: 0.71, Recall=0.78, specificity=0.65, precision=0.67, F1=0.72, GM=0.71, FPR=0.35
# Fold:3
# Accuracy: 0.58, Recall=0.66, specificity=0.47, precision=0.66, F1=0.66, GM=0.55, FPR=0.53
# Fold:4
# Accuracy: 0.64, Recall=0.71, specificity=0.48, precision=0.74, F1=0.73, GM=0.58, FPR=0.52
# Fold:5
# Accuracy: 0.70, Recall=0.74, specificity=0.63, precision=0.79, F1=0.76, GM=0.68, FPR=0.37
# Fold:6
# Accuracy: 0.75, Recall=0.91, specificity=0.39, precision=0.78, F1=0.84, GM=0.60, FPR=0.61
# Fold:7
# Accuracy: 0.77, Recall=0.81, specificity=0.65, precision=0.85, F1=0.83, GM=0.73, FPR=0.35
# Fold:8
# Accuracy: 0.68, Recall=0.77, specificity=0.50, precision=0.77, F1=0.77, GM=0.62, FPR=0.50
# Fold:9
# Accuracy: 0.66, Recall=0.70, specificity=0.58, precision=0.76, F1=0.73, GM=0.64, FPR=0.42
# =======================================AVERAGE OVER K-FOLD===================================
# Accuracy: 0.69, Recall=0.76, specificity=0.55, precision=0.76, F1=0.76, GM=0.64, FPR=0.45

# %%
conf_matrix
# Out:
# array([[35, 11],
#        [15, 15]])

# %%
tree.plot_tree(clf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-a6474032df23> in <cell line: 1>()
# ----> 1 tree.plot_tree(clf)
#
# NameError: name 'tree' is not defined
