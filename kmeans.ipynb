# %% [markdown]
# # Clustering using K-Means

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/MyDrive
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive

# %%
# !ls
# Out:
#  22021002001006_Anandkumar_Digital.pdf
# '22021002001006-Anand kumar dsa.pdf'
#  AIML
# 'AIML LAB c'
# 'ANAND IMAGE.jpg'
# 'Anand Kumar 22021002001006.pdf'
# 'Anand Kumar B. tech Lat. CSE_Admission slip.pdf'
# 'Anand Kumar CV.pdf'
# 'Anand Kumar.pdf'
#  apy_1.gsheet
#  boat.CPP
# 'Cafe BDA.pdf'
# 'cafe - cafe (1).gsheet'
# 'cafe - cafe.gsheet'
# 'CG LAB'
#  Classification
#  Classroom
# 'Colab Notebooks'
# 'cyr-wgmq-qdz - Jul 3, 2022 (1).gjam'
# 'cyr-wgmq-qdz - Jul 3, 2022 (2).gjam'
# 'cyr-wgmq-qdz - Jul 3, 2022.gjam'
# 'DBMS Lab Assignment 1.gdoc'
# 'DLS sessional ( ANAND KUMAR EE 35).pdf'
# 'EEC TEST ( Anand Kumar EE 35).pdf'
#  googleplaystore.gsheet
# 'Housing BDA.pdf'
# 'housing_dataset - housing_dataset (1) (1).gsheet'
# 'housing_dataset - housing_dataset (1).gsheet'
# 'Illumination t - 2 Anand Kumar EE 35.pdf'
#  IMG_20220605_161804.jpg
#  IMG_20230215_000258.jpg
#  IndiDrive
# 'IndiDrive (1)'
# 'Interconnected power system(Anand Kumar EE 35) (1).pdf'
# 'Interconnected power system(Anand Kumar EE 35).pdf'
#  Lab1.gdoc
# 'Lab 3 Questions.gdoc'
# 'Lab Assignment 2  .gdoc'
# 'Merge Sort (2).gdoc'
# 'Performance_of_Students (1).gsheet'
#  Performance_of_Students.gsheet
# 'permutation and combination_MCA.gdoc'
#  pic.jpg
#  pimg.jpg
# 'Principle of Mathematical Induction.gdoc'
#  Project
# 'PS 2 ANAND KUMAR EE 35.pdf'
#  Resume
# "Share 'Programming in C-1.pptx'.gslides"
#  signature.jpg
# 'soft computing'
# 'statement and arguments.gslides'
# 'Statement and Assumption.gslides'
# 'The Joy of Computing using Python:English.gdoc'
# 'titanic (1).gsheet'
#  titanic.gsheet
# 'train (1).gsheet'
#  train.gsheet
# 'tweets_covid19 (1).gsheet'
# 'tweets_covid19 (2).gsheet'
#  tweets_covid19.gsheet
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'Weather Prediction ppt.pdf'
# 'Weather prediction report.pdf'
#  work.gdoc
# 'Workshop project group 6.pdf'
#  work.txt

# %%
from scipy.io import loadmat
#path="/content/drive/MyDrive/UEM/AIML LAB/Classification/"
path="/content/drive/MyDrive/AIML/Classification/"
data = loadmat(path+'pima_dataset.mat')
X=data['norm_data']
y=data['target']
X.shape
# Out:
# (768, 8)

# %%
X
# Out:
# array([[0.35294118, 0.74371859, 0.59016393, ..., 0.50074516, 0.23441503,
#         0.48333333],
#        [0.05882353, 0.42713568, 0.54098361, ..., 0.39642325, 0.11656704,
#         0.16666667],
#        [0.47058824, 0.91959799, 0.52459016, ..., 0.34724292, 0.25362938,
#         0.18333333],
#        ...,
#        [0.29411765, 0.6080402 , 0.59016393, ..., 0.390462  , 0.07130658,
#         0.15      ],
#        [0.05882353, 0.63316583, 0.49180328, ..., 0.4485842 , 0.11571307,
#         0.43333333],
#        [0.05882353, 0.46733668, 0.57377049, ..., 0.45305514, 0.10119556,
#         0.03333333]])

# %%
import numpy as np
import math
from sklearn.model_selection import train_test_split
from sklearn import datasets
from sklearn.cluster import KMeans

# %%
from sklearn.metrics import *

# %%
kmeans = KMeans(n_clusters=3, random_state=0).fit(X)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans.cluster_centers_
# Out:
# array([[0.13803681, 0.52363042, 0.50165946, 0.14005081, 0.03984104,
#         0.42739982, 0.13583246, 0.0896728 ],
#        [0.11142534, 0.68505991, 0.60052806, 0.34897047, 0.20265616,
#         0.5453614 , 0.21660686, 0.13052885],
#        [0.45098039, 0.6554353 , 0.62638363, 0.17551584, 0.07393769,
#         0.48464468, 0.17019751, 0.42863248]])

# %%
davies_bouldin_score(X,kmeans.labels_)
# Out:
# 1.699237769219742
